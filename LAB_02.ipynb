# %%
#LAB 2

# %%
1. Write a Python Program to check weather a Given Number is odd or Even.

2. Write a program to display “Hello” if a number entered by user is a multiple of five , otherwise
print “Bye”.

3. Write a Python Program to Check weather a candidate Eligible (18 years of age) for Vote or not.
Ask the age from the user.

4.. Write a program that interprets the Body Mass Index (BMI) based on a user’s weight and height.
It should tell them the interpretation of their BMI based on the BMI value.
• Under 18.5 they are underweight
• Over 18.5 but below 25 they have a normal weight
• Over 25 but below 30 they are slightly overweight
• Over 30 but below 35 they are obese
• Above 35 they are clinically obese.
The BMI is calculated by dividing a person’s weight (in kg) by the square of their height (in m) .
Take height and weight from the user.

# %%
#Ques.1
a = int(input("Enter a no. "))
if a%2 == 0:
    print("THE NO. IS EVEN!")
else:
    print("THE NO. IS ODD!")
# Out:
# Enter a no.  2887
# THE NO. IS ODD!

# %%
#Ques.2
n = int(input("Enter a no. "))
if n%5 == 0:
    print("Hello!")
else:
    print("Bye!")
# Out:
# Enter a no.  35678870
# Hello!

# %%
#Ques.3
x = int(input("Enter your age:"))
y = 18

if x>=y:
    print("YOU ARE ELIGIBLE TO VOTE!")
else:
    print("YOU ARE NOT ELIGIBLE TO VOTE")
# Out:
# Enter your age: 42
# YOU ARE ELIGIBLE TO VOTE!

# %%
#Ques.4
A = float(input("Enter your weight in kgs:"))
B = float(input("Enter your height in m:"))

BMI = A/(B*B)
print("Your BMI is," , BMI)
if BMI <= 18.5:
    print("Your are underweight!")
elif 18.5 < BMI <= 25:
    print("You have normal weight!")
elif 25 < BMI <= 30:
    print("You are slightly overweight!")
elif 30 < BMI <= 35:
    print("You are obese!")
else:
    print("You are clinically obese!")
# Out:
# Enter your weight in kgs: 60
# Enter your height in m: 1.58
# Your BMI is, 24.034609838166958
# You have normal weight!
